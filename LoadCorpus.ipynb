# %% [markdown]
# **Vaidehi Kale - 25**

# %%
with open("/content/sample_data/mental_health.csv", 'r', encoding='utf-8') as file:
  text = file.read()

# %%
from nltk.corpus.reader.plaintext import PlaintextCorpusReader
corpus = PlaintextCorpusReader('/content/sample_data/mental_health.csv', '.*')
